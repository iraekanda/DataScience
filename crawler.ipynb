# %%
# from operator import itemgetter
from math import log, sqrt
from collections import defaultdict
import nltk
import os

inverted_index = defaultdict(list)
nos_of_documents = 0
vects_for_docs = []  # we will need nos of docs number of vectors, each vector is a dictionary
vect5_for_docs = {}
document_freq_vect = {}  # sort of equivalent to initializing the number of unique words to 0
address=""
import sys
reload(sys)
sys.setdefaultencoding("ISO-8859-1")

def getfolderaddress():
	global address
	address = raw_input("Plese enter folder address \n")
	while True: 
		if address=='9' :
			exit()
		elif os.path.isdir(address):
			break
		else :
			address = raw_input("Enter correct address(if want to quit press 9) \n")

def finddocument():
    global nos_of_documents
    x=address
    count=0
    for file in os.listdir(x):
        count=count+1
    nos_of_documents = count+1
# this is the first function that is executed.
# It updates the vects_for_docs variable with vectors of all the documents.
def iterate_over_all_docs():
    x=address  
    for file in os.listdir(x):
        doc_text = get_document_text_from_doc_id(x,file)
        token_list = get_tokenized_and_normalized_list(doc_text)
        vect = create_vector(token_list)
        vects_for_docs.append(vect)


# creates a vector from a query in the form of a list (l1) , vector is a dictionary, containing words:frequency pairs
def create_vector_from_query(l1):
    vect = {}
    for token in l1:
        if token in vect:
            vect[token] += 1.0
        else:
            vect[token] = 1.0
    return vect


# name is self explanatory, it generates and inverted index in the global variable inverted_index,
# however, precondition is that vects_for_docs should be completely initialized
def generate_inverted_index(): 
    for file in os.listdir(address):
    	lineno=1
    	vect5=defaultdict(list)
        f=address+'/'+file
        lines=open(f).read().splitlines()
        ps = nltk.stem.PorterStemmer()
        for line in lines:
        	tokens = nltk.word_tokenize(line)
        	for word in tokens:
        		vect5[ps.stem(word)].append(lineno)
        	lineno=lineno+1;		
	vect5_for_docs[file] = vect5

# it updates the vects_for_docs global variable (the list of frequency vectors for all the documents)
# and changes all the frequency vectors to tf-idf unit vectors (tf-idf score instead of frequency of the words)
def create_tf_idf_vector():
    for vect in vects_for_docs:
        vect_length = 0.0
        for word1 in vect:
            word_freq = vect[word1]
            temp = calc_tf_idf(word1, word_freq)
            vect[word1] = temp
            vect_length += temp ** 2

        vect_length = sqrt(vect_length)
        if vect_length != 0:
        	for word1 in vect:
        		vect[word1] /= vect_length


# note: even though you do not need to convert the query vector into a unit vector,
# I have done so because that would make all the dot products <= 1
# as the name suggests, this function converts a given query vector
# into a tf-idf unit vector(word:tf-idf vector given a word:frequency vector
def get_tf_idf_from_query_vect(query_vector1):
    vect_length = 0.0
    for word1 in query_vector1:
        word_freq = query_vector1[word1]
        if word1 in document_freq_vect:  # I have left out any term which has not occurred in any document because
            query_vector1[word1] = calc_tf_idf(word1, word_freq)
        else:
            query_vector1[word1] = log(1 + word_freq) * log(
                nos_of_documents)  # this additional line will ensure that if the 2 queries,
            # the first having all words in some documents,
            #   and the second having and extra word that is not in any document,
            # will not end up having the same dot product value for all documents
        vect_length += query_vector1[word1] ** 2
    vect_length = sqrt(vect_length)
    if vect_length != 0:
        for word1 in query_vector1:
            query_vector1[word1] /= vect_length


# precondition: word is in the document_freq_vect
# this function calculates the tf-idf score for a given word in a document
def calc_tf_idf(word1, word_freq):
    return log(1 + word_freq) * log(nos_of_documents / document_freq_vect[word1])


# define a number of functions,
# function to to read a given document word by word and
# 1. Start building the dictionary of the word frequency of the document,
#       2. Update the number of distinct words
#  function to :
#       1. create the dictionary of the term freqency (number of documents which have the terms);


# this function returns the dot product of vector1 and vector2
def get_dot_product(vector1, vector2):
    if len(vector1) > len(vector2):  # this will ensure that len(dict1) < len(dict2)
        temp = vector1
        vector1 = vector2
        vector2 = temp
    keys1 = vector1.keys()
    keys2 = vector2.keys()
    sum = 0
    for i in keys1:
        if i in keys2:
            sum += vector1[i] * vector2[i]
    return sum





# this function returns a list of tokenized and stemmed words of any text
def get_tokenized_and_normalized_list(doc_text):
    # return doc_text.split()


    tokens = nltk.word_tokenize(doc_text)
    ps = nltk.stem.PorterStemmer()
    stemmed = []
    for words in tokens:
        stemmed.append(ps.stem(words))
    return stemmed


# creates a vector from a list (l1) , vector is a dictionary, containing words:frequency pairs
# this function should not be called to parse the query given by the user
# because this function also updates the document frequency dictionary
def create_vector(l1):
    vect = {}  # this is a dictionary
    global document_freq_vect

    for token in l1:
        if token in vect:
            vect[token] += 1
        else:
            vect[token] = 1
            if token in document_freq_vect:
                document_freq_vect[token] += 1
            else:
                document_freq_vect[token] = 1
    return vect


def get_document_text_from_doc_id(x,file):
    # noinspection PyBroadException

    try:
        str1 = open(x+'/'+file).read()
    except:
        str1 = ""
    return str1


# this function takes the dot product of the query with all the documents
#  and returns a sorted list of tuples of docId, cosine score pairs
def get_result_from_query_vect(query_vector1):
    parsed_list = []
    x=address
    count=0;
    for file in os.listdir(x):
        dot_prod = get_dot_product(query_vector1, vects_for_docs[count])
        parsed_list.append((file, dot_prod))
        parsed_list = sorted(parsed_list, key=lambda x: x[1])
        count=count+1
    return parsed_list


# now the actual execution starts (this is equivalent to the main function of java)

getfolderaddress()

# find no. of documents in folder
finddocument()

# initializing the vects_for_docs variable
iterate_over_all_docs()

# self explanatory
generate_inverted_index()

# changes the frequency values in vects_for_docs to tf-idf values
create_tf_idf_vector()

# print("Here is a list of 15 tokens along with its docIds (sorted) in the inverted index")
# count = 1
# for word in inverted_index:
#     if count >= 16:
#         break
#     print('token num ' + str(count) + ': ' + word + ': '),
#     for docId in inverted_index[word]:
#         print(str(docId) + ', '),
#     print()
#     count += 1

# print vect5_for_docs

while True:
    query = raw_input("Please enter your query....")
    if len(query) == 0:
        break
    query_list = get_tokenized_and_normalized_list(query)
    query_vector = create_vector_from_query(query_list)
    get_tf_idf_from_query_vect(query_vector)
    result_set = get_result_from_query_vect(query_vector)

    for tup in result_set:
        print("The docname is " + str(tup[0]) + " and the weight is " + str(tup[1]))
        x = set()
        for word in query_list:
            for num in vect5_for_docs[str(tup[0])][word]:
                x.add(num)
        for t in x:
            print t

# %%
import requests

URL = 'https://www.umm.ac.id'

page = requests.get(URL)

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page.content, 'html.parser')

# %%
so
#  " name="description"/>,
#  <meta content="umm,muhammadiyah,malang,kampus,putih,indonesia,1964,dari muhammadiyah untuk bangsa,organisasi,universitas,perguruan tinggi,ptm,institusi,jawa timur,east java,fakultas,program studi,akademik,sekolah tinggi" name="keywords"/>,
#  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>,
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>,
#  <meta content="width=device-width, initial-scale=1 user-scalable=yes" name="viewport"/>,
#  <meta content="index, follow" name="robots"/>,
#  <meta content="Copyright 2016. University of Muhammadiyah Malang. All Rights Reserved." name="copyright"/>,
#  <meta content="9N3NGVEzXxDMDePoHxydCy_MCvRE-fC8m-fDCsRDxYs" name="google-site-verification"/>,
#  <meta content="DF366B334136A2BA1CEBE3F5A7273EBD" name="msvalidate.01"/>,
#  <meta content="e567a01019875876" name="y_key"/>,
#  <meta content="Universitas Muhammadiyah Malang | dari Muhammadiyah untuk Bangsa" property="og:title"/>,
#  <meta content="http://www.umm.ac.id/" property="og:url"/>,
#  <meta content="http://www.umm.ac.id/themes/umm10/images/logo.png" property="og:image"/>,
#  <meta content="http://www.umm.ac.id/" property="og:site_name"/>,
#  <meta content="&lt;p&gt;
#   Universitas Muhammadiyah Malang (UMM) adalah perguruan tinggi swasta terakreditasi dengan Nomor SK: 074/SK/BAN-PT/Ak-IV/PT/II/2013, yang berpusat di kampus III terpadu Universitas Muhammadiyah Malang, Jalan Raya Tlogomas 246 Kota Malang, Jawa Timur. Universitas yang berdiri pada tahun 1964 ini berinduk pada organisasi Muhammadiyah dan merupakan perguruan tinggi Muhammadiyah terbesar di Jawa Timur. UMM termasuk dalam jajaran PTS terkemuka di Indonesia. Oleh karena didominasi warna dinding putih, UMM sering disebut sebagai kampus putih. UMM merupakan salah satu universitas yang tumbuh cepat, sehingga oleh PP Muhammadiyah diberi amanat sebagai perguruan tinggi pembina untuk seluruh PTM (Perguruan Tinggi Muhammadiyah) wilayah Indonesia Timur. Program-program yang didisain dengan cermat menjadikan UMM sebagai The Real University, yaitu universitas yang benar-benar universitas dalam artian sebagai institusi pendidikan tinggi yang selalu komit dalam mengembangkan Tri Darma Perguruan Tinggi. Pada sekarang ini Universitas Muhammadiyah Malang (UMM) menempati 3 lokasi kampus, yaitu kampus I di Jalan Bandung 1, kampus II di Jalan Bendungan Sutami 188 A dan kampus III di Jalan Raya Tlogomas 246. Kampus satu yang merupakan cikal bakal UMM, dan sekarang ini dikonsentrasikan untuk program Pasca Sarjana. Sedangkan kampus II yang dulu merupakan pusat kegiatan utama , sekarang di konsentrasikan sebagai kampus Fakultas Kedokteran dan Fakultas Ilmu Kesehatan. Sedangkan kampus III sebagai kampus terpadu dijadikan sebagai pusat sari seluruh aktivitas.&lt;/p&gt;
#  " property="og:description"/>,
#  <meta content="Universitas Muhammadiyah Malang | dari Muhammadiyah untuk Bangsa" name="twitter:title"/>,
#  <meta content="&lt;p&gt;
#   Universitas Muhammadiyah Malang (UMM) adalah perguruan tinggi swasta terakreditasi dengan Nomor SK: 074/SK/BAN-PT/Ak-IV/PT/II/2013, yang berpusat di kampus III terpadu Universitas Muhammadiyah Malang, Jalan Raya Tlogomas 246 Kota Malang, Jawa Timur. Universitas yang berdiri pada tahun 1964 ini berinduk pada organisasi Muhammadiyah dan merupakan perguruan tinggi Muhammadiyah terbesar di Jawa Timur. UMM termasuk dalam jajaran PTS terkemuka di Indonesia. Oleh karena didominasi warna dinding putih, UMM sering disebut sebagai kampus putih. UMM merupakan salah satu universitas yang tumbuh cepat, sehingga oleh PP Muhammadiyah diberi amanat sebagai perguruan tinggi pembina untuk seluruh PTM (Perguruan Tinggi Muhammadiyah) wilayah Indonesia Timur. Program-program yang didisain dengan cermat menjadikan UMM sebagai The Real University, yaitu universitas yang benar-benar universitas dalam artian sebagai institusi pendidikan tinggi yang selalu komit dalam mengembangkan Tri Darma Perguruan Tinggi. Pada sekarang ini Universitas Muhammadiyah Malang (UMM) menempati 3 lokasi kampus, yaitu kampus I di Jalan Bandung 1, kampus II di Jalan Bendungan Sutami 188 A dan kampus III di Jalan Raya Tlogomas 246. Kampus satu yang merupakan cikal bakal UMM, dan sekarang ini dikonsentrasikan untuk program Pasca Sarjana. Sedangkan kampus II yang dulu merupakan pusat kegiatan utama , sekarang di konsentrasikan sebagai kampus Fakultas Kedokteran dan Fakultas Ilmu Kesehatan. Sedangkan kampus III sebagai kampus terpadu dijadikan sebagai pusat sari seluruh aktivitas.&lt;/p&gt;
#  " name="twitter:description"/>,
#  <meta content="http://www.umm.ac.id/themes/umm10/images/logo.png" name="twitter:image"/>,
#  <meta content="http://www.umm.ac.id/themes/umm10/images/logo.png" itemprop="image"/>,
#  <meta charset="utf-8" data-value="http://www.umm.ac.id" name="site_url"/>]

# %% [markdown]
# #GET LINK from HREF

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://www.facebook.com/ummcampus
# http://twitter.com/UMMcampus
# https://www.instagram.com/ummcampus/
# https://www.youtube.com/UMMtube
# http://www.umm.ac.id/id/
# http://www.umm.ac.id/en/
# http://www.umm.ac.id/ar/
# https://www.umm.ac.id
# /id/pages/fakultas-dan-jurusan-2.html
# /id/pages/kontak.html
# /id/pages/tentang-website.html
# #
#  /id/pages/penerimaan-mahasiswa.html
# https://pmb.umm.ac.id/
# http://openhouse.umm.ac.id/
# https://iro.umm.ac.id/
#  /id/pages/profil.html
# /id/pages/profil-singkat.html
# /id/pages/tentang-umm.html
# /id/pages/akreditasi.html
# /id/pages/staf-dan-fasilitas.html
# /id/pages/kerjasama.html
# /id/pages/pengembangan-baru.html
# /id/pages/dari-rektor.html
# /id/pages/kontak.html
# /id/pages/umm-peduli.html
#  /id/pages/mahasiswa.html
# /id/pages/yuk-keliling-kampus-kita.html
# /id/pages/kalender-akademik-11.html
# /id/pages/fasilitas-mahasiswa.html
# /id/pages/beasiswa-2.html
# /id/pages/aktivitas-mahasiswa.html
# /id/pages/situs-organisasi-mahasiswa.html
# /id/pages/distirbusi-mahasiswa-aktif.html
# https://student-site.umm.ac.id/
#  /id/pages/pendidikan.html
# https://vokasi.umm.ac.id/
# https://www.umm.ac.id/id/pages/fakultas-dan-jurusan-2.html
# https://pascasarjana.umm.ac.id/
# https://bipa.umm.ac.id/en/pages/jenis-program.html
# /id/pages/studi-di-umm-2.html
# https://infokhs.umm.ac.id/
# https://infobaa.umm.ac.id/id/pages/kalender-akademik-11.html
#  /id/pages/penelitian-dan-publikasi.html
# https://dp2m.umm.ac.id/id/pages/profil.html
# /id/pages/laboratorium-central-berstandar-internasional.html
# /id/pages/program-pengabdian.html
# /id/pages/program-penelitian.html
# /id/pages/publikasi.html
# https://hki.umm.ac.id/id/pages/profil.html
#  /id/pages/alumni-43.html
# https://pascasarjana.umm.ac.id/
# https://psppi.umm.ac.id/
# https://www.umm.ac.id
# javascript:void(0)
# https://www.umm.ac.id/id/
# https://www.umm.ac.id/en/
# https://www.umm.ac.id/ar/
# https://www.umm.ac.id/id/pages/penerimaan-mahasiswa.html
# https://www.umm.ac.id/id/pages/profil.html
# https://www.umm.ac.id/id/pages/mahasiswa.html
# https://www.umm.ac.id/id/pages/pendidikan.html
# https://www.umm.ac.id/id/pages/penelitian-dan-publikasi.html
# https://www.umm.ac.id/id/pages/staf-dan-fasilitas.html
# https://www.umm.ac.id/id/pages/tentang-website.html
# https://www.umm.ac.id/id/pages/alumni-43.html
# https://www.umm.ac.id/id/berita/susu-panggang-ide-unik-mahasiswa-umm-ajak-masyarakat-mandiri.html
# https://www.umm.ac.id/id/berita/menko-pmk-dorong-maba-berprestasi-di-penutupan-pesmaba-umm.html
# https://www.youtube.com/watch?v=hQuVOOPYWpY
#
# #carousel-example-generic
# #carousel-example-generic
# http://online.umm.ac.id
# http://online.umm.ac.id
# http://pmb.umm.ac.id
# http://pmb.umm.ac.id
# https://flipbookpdf.net/web/site/c410b2d5ca462d142c005eeb5ae8694bdcd29768202103.pdf.html
# https://flipbookpdf.net/web/site/c410b2d5ca462d142c005eeb5ae8694bdcd29768202103.pdf.html
# http://www.umm.ac.id/id/pages/akreditasi.html
# http://www.umm.ac.id/id/pages/akreditasi.html
# https://api.whatsapp.com/send?phone=6285215219000
# https://api.whatsapp.com/send?phone=6285215219000
# http://www.umm.ac.id/id/berita.html
# https://www.umm.ac.id/id/berita/teknik-mesin-umm-pamerkan-karya-futuristik-di-mexpo-2021.html
# https://www.umm.ac.id/id/berita/teknik-mesin-umm-pamerkan-karya-futuristik-di-mexpo-2021.html
# https://www.umm.ac.id/id/berita/tim-umm-juara-kontes-robot-sar-indonesia.html
# https://www.umm.ac.id/id/berita/tim-umm-juara-kontes-robot-sar-indonesia.html
# https://www.umm.ac.id/id/berita/rektor-umm-lantik-sepuluh-dekan-baru.html
# https://www.umm.ac.id/id/berita/rektor-umm-lantik-sepuluh-dekan-baru.html
# https://www.umm.ac.id/id/berita/mahasiswa-umm-ciptakan-antibakteri-dari-daun-belimbing-wuluh.html
# http://twitter.com/UMMcampus
# https://plus.google.com/+UMMtube/
# https://www.instagram.com/ummcampus/
# https://www.youtube.com/UMMtube
# https://www.flickr.com/university-of-muhammadiyah-malang/
# https://www.umm.ac.id/id/subdomain.html
# /id/pages/umm-feeds.html
# https://www.umm.ac.id/id/sitemap.html
# https://www.muhammadiyah.or.id

# %%
print(soup.get_text())
# Out:
# Universitas Muhammadiyah Malang | dari Muhammadiyah untuk Bangsa
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ID
# |
# EN
# |
# AR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fakultas dan JurusanKontakTentang Website
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                         function show_menu() {
#                                                            var element = document.getElementById("show_m");
#                                                            element.classList.toggle("h_menu100");
#                                                         }
#
# Penerimaan Mahasiswa Baru
#
# Info PendaftaranVirtual Open House UMM 2021Program Internasional
#
#
# Profil
#
# Profil SingkatTentang UMMAkreditasiStaf dan FasilitasKerjasamaPengembangan Unit Bisnis UMMPimpinan UMMKontakPeduli Covid19
#
#
# Mahasiswa
#
# Yuk Keliling KampusKalender Akademik 2020/2021Fasilitas MahasiswaBeasiswaAktivitas MahasiswaSitus Organisasi MahasiswaDistribusi Mahasiswa AktifCari Mahasiswa
#
#
# Akademik
#
# VokasiSarjanaPascasarjanaBIPA (Bahasa Inggris untuk Penutur Asing)Studi di UMMKartu Hasil StudiKalender Akademik
#
#
#
#
#
#
#
# Riset dan Publikasi
#
# Direktorat Penelitian dan Pengabdian Kepada MasyarakatLaboratorium Central Berstandar InternasionalProgram PengabdianProgram PenelitianPublikasiSentra HKI dan Paten
#
#
# Alumni
#
# Pascasarjana Program profesi Insinyur
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Indonesia
# |
# English
# |
# Arabic
#
#
#
#
#
#
#
#
#
#
#
#
#
# Penerimaan Mahasiswa Baru
#
#
# Profil
#
#
# Mahasiswa
#
#
# Akademik
#
#
# Riset dan Publikasi
#
#
# Staf dan Fasilitas
#
#
# Tentang Website
#
#
# Alumni
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SUSU PANGGANG
#
#
#
#
#
#
#
# maba 2021
#
#
#
#
#
#
#
# VIdeo pesmaba 2021
#
#
#
#
#
#
#
# banner Unggul
#
#
#
#
#
#
# Previous
#
#
#
# Next
#
#
#
#
#
#
#
#
#
#
# INFORMASI MAHASISWA BARU
#
#
#
#
#
#
#
#
#
#
# DAFTAR
#
#
#
#
#
#
#
# INFORMASI
#
#
#
#
#
#
#
# BOOKLET
#
#
#
#
#
#
#
# AKREDITASI
#
#
#
#
#
#
#
#
# WhatsApp Center
# Penerimaan Mahasiswa Baru
# 085215219000
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Berita UMM
#
#
#
#
#
#
#
#
#
#
#
#
#
# Teknik Mesin UMM Pamerkan Karya Futuristik di Mexpo
#
#
#
#
#
#
#
#
#
#
#
# Tim UMM Juara Kontes Robot SAR Indonesia
#
#
#
#
#
#
#
#
#
#
#
# Rektor UMM Lantik Sepuluh Dekan Baru
#
#
#
#
#
#
#
#
#
#
#
# Mahasiswa UMM Ciptakan Antibakteri dari Daun Belimbing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Pengumuman
#
#
#
#
#
#
# Daftar Plotting Mahasiswa dan Dosen Pembimbing Teknologi Pangan UMM
#  Rabu, 06 Oktober 2021
# Silahkan download file di
#
#
#
# Panduan Talenta Inovasi 2021
#  Rabu, 06 Oktober 2021
# Program Talenta Inovasi Indonesia merupakan program pendanaan berupa
#
#
#
#
#
#
#
#
#  Beasiswa
#
#
#
#
#
#
# BEASISWA CENDIKIA BAZNAS (BCB) 2021
#  Rabu, 25 Agustus 2021
# SILAHKAN UNDUH INFO BEASISWA
#
#
#
# Beasiswa Mahasiswa UMM
#  Sabtu, 14 Agustus 2021
# klik info Beasiswa Mahasiswa Baru klik info Beasiswa Mahasiswa
#
#
#
#
#
#
#
#
#  Karir
#
#
#
#
#
#
# English First Eduka Group Recruitment Teachers
#  Senin, 30 Agustus 2021
# English First Recruitment Teachers    Please click
#
#
#
# English First Eduka Group Recruitment Teachers
#  Senin, 30 Agustus 2021
# English First Recruitment Teachers    Please click
#
#
#
#
#
#
#
#
#
#
# AGENDA
#
# 02-November-2021
# PROGRAM KOLABORASI UMM DAN NUTRIFOOD
#
# 03-November-2021
# PROGRAM KOLABORASI UMM DAN NUTRIFOOD
#
# 04-November-2021
# PROGRAM KOLABORASI UMM DAN NUTRIFOOD
#
# 05-November-2021
# PROGRAM KOLABORASI UMM DAN NUTRIFOOD
#
#
#
#
#
#
#
#
#
#
#
#
# Virtual Campus Tour Pesmaba UMM 2021
#
#
#
#
#
#
#
#
# UMM dalam Media
#
#
# Twitter
#
#
# Instagram
#
#
#
#
#
#
# Urgensi Vaksinasi Anak Sebelum Sekolah
#
#
#
#
#  Kamis, 09 September 2021 11:13 WIB
# 			 Universitas Muhammadiyah Malang
# 			 Bhirawa - Bhirawa
#
# Bhirawa, Kamis, 09 September 2021, Hal. 4 selengkapnya
#
# Twibbon Kemerdekaan
#
#
#
#
#  Kamis, 19 Agustus 2021 11:05 WIB
# 			 Universitas Muhammadiyah Malang
# 			 New Malang Pos.id - New Malang Pos.id
#
# New Malang Pos, Kamis, 19 Agustus 2021, Hal. 1 selengkapnya
#
# Peningkatan dan Pengkualitasan SDM Pertanian
#
#
#
#
#  Kamis, 19 Agustus 2021 11:02 WIB
# 			 Universitas Muhammadiyah Malang
# 			 Bhirawa - Bhirawa
#
# Bhirawa, Kamis, 19 Agutus 2021, Hal. 4 selengkapnya
#
# Sumbangsih FKIP UMM Dorong Profesionalisme Guru
#
#
#
#
#  Kamis, 19 Agustus 2021 10:28 WIB
# 			 Universitas Muhammadiyah Malang
# 			 Jawa Pos - Jawa Pos
#
# Jawa Pos, Kamis, 19 Agustus 2021, Hal. 6 selengkapnya
#
# Semangat Kemerdekaan Kampus Putih Hadapi Pandemi
#
#
#
#
#  Rabu, 18 Agustus 2021 14:03 WIB
# 			 Universitas Muhammadiyah Malang
# 			 Jawa Pos - Jawa Pos
#
# Jawa Pos, Rabu, 18 Agustus 2021, Hal. 16 selengkapnya
#
# Sutradara Terbaik
#
#
#
#
#  Rabu, 18 Agustus 2021 13:44 WIB
# 			 Universitas Muhammadiyah Malang
# 			 Jawa Pos - Jawa Pos
#
# Jawa Pos, Rabu, 18 Agustus 2021, Hal. 2 selengkapnya
#
# Tekan Jumlah Perokok Anak
#
#
#
#
#  Selasa, 03 Agustus 2021 10:10 WIB
# 			 Universitas Muhammadiyah Malang
# 			 
WIB
# 			 Universitas Muhammadiyah Malang
# 			 Harian Dis Way - Harian Dis Way
#
# Harian Di's Way: Edukasi, Selasa, 13 Juli 2021, Hal. 14 selengkapnya
#
# Komitmen Memajukan Pertanian di Era 5.0
#
#
#
#
#  Kamis, 15 Juli 2021 10:20 WIB
# 			 Universitas Muhammadiyah Malang
# 			 Bhirawa - Bhirawa
#
# Bhirawa, Selasa, 13 Juli 2021, Hal. 4 selengkapnya
#
#
#
# Tweets by UMMCAMPUS
# !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+"://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# UMM FACT
#
#
#
#
#
#
#
#
# Mahasiswa
# Prestasi
# Akademik
# Kerjasama
#
#
#
#
#
#
#
#
# 35.204
# Total Mahasiswa 2021
#
#
#
#
# 7.500
# Mahasiswa Baru 2020
#
#
#
#
# 84
# Mahasiswa Asing 2021
#
#
#
#
# 105.734
# Alumni 2021
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 40
# Program Sarjana
#
#
#
#
# 10
# Fakultas
#
#
#
#
# 13
# Pascasarjana
#
#
#
#
# 6
# Program Profesi
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Galeri
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Menu
#
#
#
#                                                 Penerimaan Mahasiswa Baru
#
#
#
#                                                 Profil
#
#
#
#                                                 Mahasiswa
#
#
#
#                                                 Akademik
#
#
#
#                                                 Riset dan Publikasi
#
#
#
#                                                 Staf dan Fasilitas
#
#
#
#
#
#
#
#
# Kategori
#
# Berita UMM
# Pengumuman
# Beasiswa
# Karir
# Agenda
# Galeri
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             Kampus I
#                             Jl. Bandung 1 Malang, Jawa TimurPhone: +62 341 551 253 (Hunting)Fax: +62 341 460 435
#
#
#
#
#
#                             Kampus II
#                             Jl. Bendungan Sutami No.188 Malang, Jawa TimurPhone: +62 341 551 149 (Hunting)Fax: +62 341 582 060
#
#
#
#
#
#                             Kampus III
#                             Jl. Raya Tlogomas No.246 Malang, Jawa TimurPhone: +62 341 464 318 (Hunting)Fax: +62 341 460 435
#
#
#
#
#
#
#
#
#
#
#
#
# Daftar SubdomainUMM FeedsPeta Situs
#
#                             Developed by Infokom Universitas Muhammadiyah Malang Copyright  2020
#
#
#
#
#
#
#
#
#
#
# 		$( ".additional-nav-btn" ).click(function() {
# 			$( "#additional-nav-content" ).toggle( "slow" );
# 		});
#
#
# 		var _gaq = _gaq || [];
# 		_gaq.push(['_setAccount', 'UA-11297736-1']);
# 		_gaq.push(['_setDomainName', '.umm.ac.id']);
# 		_gaq.push(['_trackPageview']);
#
# 		(function() {
# 		var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 		ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 		var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 		})();
#
#
#
# 	function myFunction(imgs) {
# 	    var expandImg = document.getElementById("expandedImg");
# 	    var imgText = document.getElementById("imgtext");
# 	    expandImg.src = imgs.src;
# 	    imgText.innerHTML = imgs.alt;
# 	    expandImg.parentElement.style.display = "block";
# 	}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                        (function ($) {
#                         "use strict";
#                             $.scrollUp({
#                                 scrollText: '<i class="fa fa-angle-up"></i>',
#                                 easingType: 'linear',
#                                 scrollSpeed: 900,
#                                 animation: 'fade'
#                             });
#                         })(jQuery);
#
#
#         function openNav() {
#             document.getElementById("MobileSlideMenu").style.width = "100%";
#         }
#         function closeNav() {
#             document.getElementById("MobileSlideMenu").style.width = "0";
#         }
#
#
#         function open_show() {
#             document.getElementById("my_show").style.display = "block";
#             document.getElementById("close").style.display = "none";
#         }
#         function close_show() {
#             document.getElementById("my_show").style.display = "none";
#             document.getElementById("close").style.display = "block";
#         }
#
#
# Muhammadiyah
